# %%
import pandas as pd

# %%
dataset = pd.read_csv("Google_Stock_Price_Train.csv" ,index_col = 0)

# %%
dataset
# Out:
#               Open    High     Low   Close      Volume
# Date
# 1/3/2012    325.25  332.83  324.97  663.59   7,380,500
# 1/4/2012    331.27  333.87  329.08  666.45   5,749,400
# 1/5/2012    329.83  330.75  326.89  657.21   6,590,300
# 1/6/2012    328.34  328.77  323.68  648.24   5,405,900
# 1/9/2012    322.04  322.29  309.46  620.76  11,688,800
# ...            ...     ...     ...     ...         ...
# 12/23/2016  790.90  792.74  787.28  789.91     623,400
# 12/27/2016  790.68  797.86  787.66  791.55     789,100
# 12/28/2016  793.70  794.23  783.20  785.05   1,153,800
# 12/29/2016  783.33  785.93  778.92  782.79     744,300
# 12/30/2016  782.75  782.78  770.41  771.82   1,770,000
#
# [1258 rows x 5 columns]

# %%
x = dataset['Open']

# %%
x
# Out:
# Date
# 1/3/2012      325.25
# 1/4/2012      331.27
# 1/5/2012      329.83
# 1/6/2012      328.34
# 1/9/2012      322.04
#                ...
# 12/23/2016    790.90
# 12/27/2016    790.68
# 12/28/2016    793.70
# 12/29/2016    783.33
# 12/30/2016    782.75
# Name: Open, Length: 1258, dtype: float64

# %%
x.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
training_set = dataset['Open']

# %%
training_set.shape
# Out:
# (1258,)

# %%
len(training_set)
# Out:
# 1258

# %%
training_set[0:60]
# Out:
# Date
# 1/3/2012     325.25
# 1/4/2012     331.27
# 1/5/2012     329.83
# 1/6/2012     328.34
# 1/9/2012     322.04
# 1/10/2012    313.70
# 1/11/2012    310.59
# 1/12/2012    314.43
# 1/13/2012    311.96
# 1/17/2012    314.81
# 1/18/2012    312.14
# 1/19/2012    319.30
# 1/20/2012    294.16
# 1/23/2012    291.91
# 1/24/2012    292.07
# 1/25/2012    287.68
# 1/26/2012    284.92
# 1/27/2012    284.32
# 1/30/2012    287.95
# 1/31/2012    290.41
# 2/1/2012     291.38
# 2/2/2012     291.34
# 2/3/2012     294.23
# 2/6/2012     296.39
# 2/7/2012     302.44
# 2/8/2012     303.18
# 2/9/2012     304.87
# 2/10/2012    302.81
# 2/13/2012    304.11
# 2/14/2012    304.63
# 2/15/2012    305.32
# 2/16/2012    300.28
# 2/17/2012    301.36
# 2/21/2012    300.81
# 2/22/2012    304.84
# 2/23/2012    302.37
# 2/24/2012    302.54
# 2/27/2012    302.16
# 2/28/2012    303.86
# 2/29/2012    308.14
# 3/1/2012     309.97
# 3/2/2012     309.84
# 3/5/2012     309.06
# 3/6/2012     302.89
# 3/7/2012     303.39
# ...

# %%
len(training_set[0:60])
# Out:
# 60

# %%
training_set[61]
# Out:
# 324.66

# %%
dependent =[]

# %%
independent = []

# %%
for i in range(0,1198):
    dependent.append(training_set[i:i+60])
    independent.append(training_set[i+60])

# %%
dependent
# Out:
# [Date
#  1/3/2012     325.25
#  1/4/2012     331.27
#  1/5/2012     329.83
#  1/6/2012     328.34
#  1/9/2012     322.04
#  1/10/2012    313.70
#  1/11/2012    310.59
#  1/12/2012    314.43
#  1/13/2012    311.96
#  1/17/2012    314.81
#  1/18/2012    312.14
#  1/19/2012    319.30
#  1/20/2012    294.16
#  1/23/2012    291.91
#  1/24/2012    292.07
#  1/25/2012    287.68
#  1/26/2012    284.92
#  1/27/2012    284.32
#  1/30/2012    287.95
#  1/31/2012    290.41
#  2/1/2012     291.38
#  2/2/2012     291.34
#  2/3/2012     294.23
#  2/6/2012     296.39
#  2/7/2012     302.44
#  2/8/2012     303.18
#  2/9/2012     304.87
#  2/10/2012    302.81
#  2/13/2012    304.11
#  2/14/2012    304.63
#  2/15/2012    305.32
#  2/16/2012    300.28
#  2/17/2012    301.36
#  2/21/2012    300.81
#  2/22/2012    304.84
#  2/23/2012    302.37
#  2/24/2012    302.54
#  2/27/2012    302.16
#  2/28/2012    303.86
#  2/29/2012    308.14
#  3/1/2012     309.97
#  3/2/2012     309.84
#  3/5/2012     309.06
# ...

# %%
independent
# Out:
# [325.5,
#  324.66,
#  319.19,
#  321.5,
#  318.03,
#  314.94,
#  313.07,
#  315.58,
#  315.8,
#  319.98,
#  322.57,
#  310.34,
#  303.14,
#  302.89,
#  301.71,
#  301.0,
#  295.34,
#  298.0,
#  300.87,
#  304.31,
#  306.36,
#  305.35,
#  300.77,
#  299.48,
#  303.67,
#  301.83,
#  296.39,
#  301.63,
#  302.28,
#  305.34,
#  304.04,
#  299.27,
#  301.54,
#  307.83,
#  315.73,
#  311.38,
#  299.13,
#  305.57,
#  299.7,
#  303.44,
#  299.38,
#  296.79,
#  292.98,
#  293.26,
#  284.83,
#  284.05,
#  286.65,
#  287.16,
#  292.7,
#  286.85,
#  291.01,
#  283.82,
#  279.81,
#  279.6,
#  279.12,
#  280.26,
#  285.72,
#  288.82,
#  288.84,
#  282.94,
#  282.61,
#  280.33,
#  282.79,
#  281.89,
#  286.41,
#  289.82,
#  288.92,
#  293.28,
#  295.12,
#  291.38,
#  293.99,
#  287.07,
#  282.5,
#  285.01,
#  287.11,
#  288.14,
#  287.41,
#  291.98,
#  303.24,
#  299.12,
#  306.35,
#  303.02,
#  306.35,
#  308.29,
#  316.84,
#  312.96,
#  317.46,
#  311.59,
#  318.81,
#  318.61,
#  319.7,
# ...

# %%
import numpy as np

# %%
np.array(dependent)
# Out:
# array([[325.25, 331.27, 329.83, ..., 321.3 , 322.31, 324.8 ],
#        [331.27, 329.83, 328.34, ..., 322.31, 324.8 , 325.5 ],
#        [329.83, 328.34, 322.04, ..., 324.8 , 325.5 , 324.66],
#        ...,
#        [774.25, 776.03, 779.31, ..., 792.36, 790.9 , 790.68],
#        [776.03, 779.31, 779.  , ..., 790.9 , 790.68, 793.7 ],
#        [779.31, 779.  , 779.66, ..., 790.68, 793.7 , 783.33]])

# %%
np.array(independent)
# Out:
# array([325.5 , 324.66, 319.19, ..., 793.7 , 783.33, 782.75])

# %%
dependent_array = np.array(dependent)

# %%
independent_array = np.array(independent)

# %%
dependent_array.shape
# Out:
# (1198, 60)

# %%
independent_array.shape
# Out:
# (1198,)

# %%
from keras.layers import LSTM

# %%
from keras.models import Sequential

# %%
model = Sequential()

# %%
model.add(LSTM(
            units = 60,
            return_sequences = True , 
            input_shape = (60 , )))
